# %%
# Now install the required libraries
# !pip install daam==0.2.0 diffusers==0.21.2 transformers==4.30.2 torch torchvision matplotlib ftfy scipy
# !pip install --upgrade huggingface_hub==0.14.1
# !pip install git+https://github.com/openai/CLIP.git
# Out:
# Collecting daam==0.2.0
#   Downloading daam-0.2.0.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Collecting diffusers==0.21.2
#   Downloading diffusers-0.21.2.tar.gz (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 15.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting transformers==4.30.2
#   Downloading transformers-4.30.2-py3-none-any.whl.metadata (113 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.6/113.6 kB 9.7 MB/s eta 0:00:00
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.20.1+cu121)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.8.0)
# Collecting ftfy
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (1.13.1)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from daam==0.2.0) (0.24.0)
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (from daam==0.2.0) (3.7.5)
# Collecting gradio (from daam==0.2.0)
#   Downloading gradio-5.6.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from daam==0.2.0) (2.2.2)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from daam==0.2.0) (0.60.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from daam==0.2.0) (3.9.1)
# Requirement already satisfied: inflect in /usr/local/lib/python3.10/dist-packages (from daam==0.2.0) (7.4.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from daam==0.2.0) (1.4.2)
# Collecting accelerate==0.23.0 (from daam==0.2.0)
#   Downloading accelerate-0.23.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: importlib_metadata in /usr/local/lib/python3.10/dist-packages (from diffusers==0.21.2) (8.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from diffusers==0.21.2) (3.16.1)
# Requirement already satisfied: huggingface-hub>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from diffusers==0.21.2) (0.26.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from diffusers==0.21.2) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from diffusers==0.21.2) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from diffusers==0.21.2) (2.32.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from diffusers==0.21.2) (0.4.5)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from diffusers==0.21.2) (11.0.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.2) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.2) (6.0.2)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers==4.30.2)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.2) (4.66.6)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate==0.23.0->daam==0.2.0) (5.9.5)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from ftfy) (0.2.13)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Collecting aiofiles<24.0,>=22.0 (from gradio->daam==0.2.0)
#   Downloading aiofiles-23.2.1-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio->daam==0.2.0) (3.7.1)
# Collecting fastapi<1.0,>=0.115.2 (from gradio->daam==0.2.0)
#   Downloading fastapi-0.115.5-py3-none-any.whl.metadata (27 kB)
# Collecting ffmpy (from gradio->daam==0.2.0)
#   Downloading ffmpy-0.4.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting gradio-client==1.4.3 (from gradio->daam==0.2.0)
#   Downloading gradio_client-1.4.3-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: httpx>=0.24.1 in /usr/local/lib/python3.10/dist-packages (from gradio->daam==0.2.0) (0.27.2)
# Collecting markupsafe~=2.0 (from gradio->daam==0.2.0)
#   Downloading MarkupSafe-2.1.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio->daam==0.2.0) (3.10.11)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio->daam==0.2.0) (2.9.2)
# Collecting pydub (from gradio->daam==0.2.0)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-multipart==0.0.12 (from gradio->daam==0.2.0)
#   Downloading python_multipart-0.0.12-py3-none-any.whl.metadata (1.9 kB)
# Collecting ruff>=0.2.2 (from gradio->daam==0.2.0)
#   Downloading ruff-0.8.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (25 kB)
# Collecting safehttpx<1.0,>=0.1.1 (from gradio->daam==0.2.0)
#   Downloading safehttpx-0.1.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting semantic-version~=2.0 (from gradio->daam==0.2.0)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting starlette<1.0,>=0.40.0 (from gradio->daam==0.2.0)
#   Downloading starlette-0.41.3-py3-none-any.whl.metadata (6.0 kB)
# Collecting tomlkit==0.12.0 (from gradio->daam==0.2.0)
#   Downloading tomlkit-0.12.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.10/dist-packages (from gradio->daam==0.2.0) (0.13.0)
# Collecting uvicorn>=0.14.0 (from gradio->daam==0.2.0)
#   Downloading uvicorn-0.32.1-py3-none-any.whl.metadata (6.6 kB)
# Collecting websockets<13.0,>=10.0 (from gradio-client==1.4.3->gradio->daam==0.2.0)
#   Downloading websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->daam==0.2.0) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->daam==0.2.0) (2024.2)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.10/dist-packages (from importlib_metadata->diffusers==0.21.2) (3.21.0)
# Requirement already satisfied: more-itertools>=8.5.0 in /usr/local/lib/python3.10/dist-packages (from inflect->daam==0.2.0) (10.5.0)
# Requirement already satisfied: typeguard>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from inflect->daam==0.2.0) (4.4.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->daam==0.2.0) (8.1.7)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->daam==0.2.0) (0.43.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers==0.21.2) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers==0.21.2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers==0.21.2) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers==0.21.2) (2024.8.30)
# Requirement already satisfied: imageio>=2.33 in /usr/local/lib/python3.10/dist-packages (from scikit-image->daam==0.2.0) (2.36.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image->daam==0.2.0) (2024.9.20)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image->daam==0.2.0) (0.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy->daam==0.2.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy->daam==0.2.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy->daam==0.2.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy->daam==0.2.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy->daam==0.2.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy->daam==0.2.0) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy->daam==0.2.0) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy->daam==0.2.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy->daam==0.2.0) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy->daam==0.2.0) (0.4.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy->daam==0.2.0) (75.1.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy->daam==0.2.0) (3.4.1)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->gradio->daam==0.2.0) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->gradio->daam==0.2.0) (1.2.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio->daam==0.2.0) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx>=0.24.1->gradio->daam==0.2.0) (0.14.0)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy->daam==0.2.0) (1.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->gradio->daam==0.2.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->gradio->daam==0.2.0) (2.23.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy->daam==0.2.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy->daam==0.2.0) (0.1.5)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio->daam==0.2.0) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio->daam==0.2.0) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy->daam==0.2.0) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy->daam==0.2.0) (7.0.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy->daam==0.2.0) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio->daam==0.2.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio->daam==0.2.0) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy->daam==0.2.0) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio->daam==0.2.0) (0.1.2)
# Downloading transformers-4.30.2-py3-none-any.whl (7.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 92.5 MB/s eta 0:00:00
# Downloading accelerate-0.23.0-py3-none-any.whl (258 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.1/258.1 kB 18.5 MB/s eta 0:00:00
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 3.1 MB/s eta 0:00:00
# Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 97.9 MB/s eta 0:00:00
# Downloading gradio-5.6.0-py3-none-any.whl (57.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.1/57.1 MB 37.1 MB/s eta 0:00:00
# Downloading gradio_client-1.4.3-py3-none-any.whl (320 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.1/320.1 kB 22.4 MB/s eta 0:00:00
# Downloading python_multipart-0.0.12-py3-none-any.whl (23 kB)
# Downloading tomlkit-0.12.0-py3-none-any.whl (37 kB)
# Downloading aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Downloading fastapi-0.115.5-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.9/94.9 kB 7.6 MB/s eta 0:00:00
# Downloading MarkupSafe-2.1.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Downloading ruff-0.8.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.1/11.1 MB 109.2 MB/s eta 0:00:00
# Downloading safehttpx-0.1.1-py3-none-any.whl (8.4 kB)
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading starlette-0.41.3-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 kB 6.5 MB/s eta 0:00:00
# Downloading uvicorn-0.32.1-py3-none-any.whl (63 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.8/63.8 kB 4.8 MB/s eta 0:00:00
# Downloading ffmpy-0.4.0-py3-none-any.whl (5.8 kB)
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Downloading websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 12.9 MB/s eta 0:00:00
# Building wheels for collected packages: daam, diffusers
#   Building wheel for daam (setup.py) ... done
#   Created wheel for daam: filename=daam-0.2.0-py3-none-any.whl size=23003 sha256=a249ad62ed83a001ebf7c6a757f8a5b4aee11e77d71c3970b565d8af5f373581
#   Stored in directory: /root/.cache/pip/wheels/d4/2a/4c/7e9586fe9895d7d9f5c8dd58f1d20cc901dc936ed48651b7c2
#   Building wheel for diffusers (pyproject.toml) ... done
#   Created wheel for diffusers: filename=diffusers-0.21.2-py3-none-any.whl size=1489273 sha256=0ebdcb06bdf771c0835c708429dc4e9790c3227b4ef075dee6ff5ddd30ed9829
#   Stored in directory: /root/.cache/pip/wheels/2e/09/32/11c9e42c397d3f3494226b28ba68c4ad4718a68a65dba14ea6
# Successfully built daam diffusers
# Installing collected packages: tokenizers, pydub, websockets, uvicorn, tomlkit, semantic-version, ruff, python-multipart, markupsafe, ftfy, ffmpy, aiofiles, starlette, transformers, safehttpx, gradio-client, fastapi, diffusers, gradio, accelerate, daam
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.20.3
#     Uninstalling tokenizers-0.20.3:
#       Successfully uninstalled tokenizers-0.20.3
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 3.0.2
#     Uninstalling MarkupSafe-3.0.2:
#       Successfully uninstalled MarkupSafe-3.0.2
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.46.2
#     Uninstalling transformers-4.46.2:
#       Successfully uninstalled transformers-4.46.2
#   Attempting uninstall: diffusers
#     Found existing installation: diffusers 0.31.0
#     Uninstalling diffusers-0.31.0:
#       Successfully uninstalled diffusers-0.31.0
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 1.1.1
#     Uninstalling accelerate-1.1.1:
#       Successfully uninstalled accelerate-1.1.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sentence-transformers 3.2.1 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.30.2 which is incompatible.
# Successfully installed accelerate-0.23.0 aiofiles-23.2.1 daam-0.2.0 diffusers-0.21.2 fastapi-0.115.5 ffmpy-0.4.0 ftfy-6.3.1 gradio-5.6.0 gradio-client-1.4.3 markupsafe-2.1.5 pydub-0.25.1 python-multipart-0.0.12 ruff-0.8.0 safehttpx-0.1.1 semantic-version-2.10.0 starlette-0.41.3 tokenizers-0.13.3 tomlkit-0.12.0 transformers-4.30.2 uvicorn-0.32.1 websockets-12.0
# Collecting huggingface_hub==0.14.1
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub==0.14.1) (3.16.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface_hub==0.14.1) (2024.10.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub==0.14.1) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub==0.14.1) (4.66.6)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub==0.14.1) (6.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub==0.14.1) (4.12.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub==0.14.1) (24.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub==0.14.1) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub==0.14.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub==0.14.1) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub==0.14.1) (2024.8.30)
# Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 3.9 MB/s eta 0:00:00
# Installing collected packages: huggingface_hub
#   Attempting uninstall: huggingface_hub
#     Found existing installation: huggingface-hub 0.26.2
#     Uninstalling huggingface-hub-0.26.2:
#       Successfully uninstalled huggingface-hub-0.26.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gradio 5.6.0 requires huggingface-hub>=0.25.1, but you have huggingface-hub 0.14.1 which is incompatible.
# gradio-client 1.4.3 requires huggingface-hub>=0.19.3, but you have huggingface-hub 0.14.1 which is incompatible.
# peft 0.13.2 requires huggingface-hub>=0.17.0, but you have huggingface-hub 0.14.1 which is incompatible.
# sentence-transformers 3.2.1 requires huggingface-hub>=0.20.0, but you have huggingface-hub 0.14.1 which is incompatible.
# sentence-transformers 3.2.1 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.30.2 which is incompatible.
# Successfully installed huggingface_hub-0.14.1
# Collecting git+https://github.com/openai/CLIP.git
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-req-build-e4svxzbf
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /tmp/pip-req-build-e4svxzbf
#   Resolved https://github.com/openai/CLIP.git to commit dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: ftfy in /usr/local/lib/python3.10/dist-packages (from clip==1.0) (6.3.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from clip==1.0) (24.2)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from clip==1.0) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from clip==1.0) (4.66.6)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from clip==1.0) (2.5.1+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from clip==1.0) (0.20.1+cu121)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from ftfy->clip==1.0) (0.2.13)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch->clip==1.0) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision->clip==1.0) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->clip==1.0) (11.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->clip==1.0) (2.1.5)
# Building wheels for collected packages: clip
#   Building wheel for clip (setup.py) ... done
#   Created wheel for clip: filename=clip-1.0-py3-none-any.whl size=1369489 sha256=44f3ee8ac78d75ac976e5042aebea09f1b1e9139c00ea0ce799f3a6fa3109cf2
#   Stored in directory: /tmp/pip-ephem-wheel-cache-854kslfc/wheels/da/2b/4c/d6691fa9597aac8bb85d2ac13b112deb897d5b50f5ad9a37e4
# Successfully built clip
# Installing collected packages: clip
# Successfully installed clip-1.0

# %%
# !pip uninstall diffusers -y
# !pip uninstall huggingface_hub -y
# Out:
# Found existing installation: diffusers 0.21.2
# Uninstalling diffusers-0.21.2:
#   Successfully uninstalled diffusers-0.21.2
# Found existing installation: huggingface-hub 0.14.1
# Uninstalling huggingface-hub-0.14.1:
#   Successfully uninstalled huggingface-hub-0.14.1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install diffusers==0.21.2
# !pip install daam
# !pip install huggingface_hub==0.14.1
# Out:
# Collecting diffusers==0.21.2
#   Using cached diffusers-0.21.2-py3-none-any.whl
# Requirement already satisfied: importlib_metadata in /usr/local/lib/python3.10/dist-packages (from diffusers==0.21.2) (8.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from diffusers==0.21.2) (3.16.1)
# Collecting huggingface-hub>=0.13.2 (from diffusers==0.21.2)
#   Downloading huggingface_hub-0.26.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from diffusers==0.21.2) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from diffusers==0.21.2) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from diffusers==0.21.2) (2.32.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from diffusers==0.21.2) (0.4.5)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from diffusers==0.21.2) (11.0.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13.2->diffusers==0.21.2) (2024.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13.2->diffusers==0.21.2) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13.2->diffusers==0.21.2) (6.0.2)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13.2->diffusers==0.21.2) (4.66.6)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13.2->diffusers==0.21.2) (4.12.2)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.10/dist-packages (from importlib_metadata->diffusers==0.21.2) (3.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers==0.21.2) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers==0.21.2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers==0.21.2) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers==0.21.2) (2024.8.30)
# Downloading huggingface_hub-0.26.2-py3-none-any.whl (447 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 447.5/447.5 kB 6.9 MB/s eta 0:00:00
# Installing collected packages: huggingface-hub, diffusers
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sentence-transformers 3.2.1 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.30.2 which is incompatible.
# Successfully installed diffusers-0.21.2 huggingface-hub-0.26.2
# Requirement already satisfied: daam in /usr/local/lib/python3.10/dist-packages (0.2.0)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from daam) (0.24.0)
# Requirement already satisfied: diffusers==0.21.2 in /usr/local/lib/python3.10/dist-packages (from daam) (0.21.2)
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (from daam) (3.7.5)
# Requirement already satisfied: gradio in /usr/local/lib/python3.10/dist-packages (from daam) (5.6.0)
# Requirement already satisfied: ftfy in /usr/local/lib/python3.10/dist-packages (from daam) (6.3.1)
# Requirement already satisfied: transformers==4.30.2 in /usr/local/lib/python3.10/dist-packages (from daam) (4.30.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from daam) (2.2.2)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from daam) (0.60.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from daam) (3.9.1)
# Requirement already satisfied: inflect in /usr/local/lib/python3.10/dist-packages (from daam) (7.4.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from daam) (1.4.2)
# Requirement already satisfied: accelerate==0.23.0 in /usr/local/lib/python3.10/dist-packages (from daam) (0.23.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate==0.23.0->daam) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate==0.23.0->daam) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate==0.23.0->daam) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate==0.23.0->daam) (6.0.2)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate==0.23.0->daam) (2.5.1+cu121)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate==0.23.0->daam) (0.26.2)
# Requirement already satisfied: importlib_metadata in /usr/local/lib/python3.10/dist-packages (from diffusers==0.21.2->daam) (8.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from diffusers==0.21.2->daam) (3.16.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from diffusers==0.21.2->daam) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from diffusers==0.21.2->daam) (2.32.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from diffusers==0.21.2->daam) (0.4.5)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from diffusers==0.21.2->daam) (11.0.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.2->daam) (0.13.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.2->daam) (4.66.6)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from ftfy->daam) (0.2.13)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /usr/local/lib/python3.10/dist-packages (from gradio->daam) (23.2.1)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio->daam) (3.7.1)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /usr/local/lib/python3.10/dist-packages (from gradio->daam) (0.115.5)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.10/dist-packages (from gradio->daam) (0.4.0)
# Requirement already satisfied: gradio-client==1.4.3 in /usr/local/lib/python3.10/dist-packages (from gradio->daam) (1.4.3)
# Requirement already satisfied: httpx>=0.24.1 in /usr/local/lib/python3.10/dist-packages (from gradio->daam) (0.27.2)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.10/dist-packages (from gradio->daam) (3.1.4)
# Requirement already satisfied: markupsafe~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio->daam) (2.1.5)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio->daam) (3.10.11)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio->daam) (2.9.2)
# Requirement already satisfied: pydub in /usr/local/lib/python3.10/dist-packages (from gradio->daam) (0.25.1)
# Requirement already satisfied: python-multipart==0.0.12 in /usr/local/lib/python3.10/dist-packages (from gradio->daam) (0.0.12)
# Requirement already satisfied: ruff>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from gradio->daam) (0.8.0)
# Requirement already satisfied: safehttpx<1.0,>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from gradio->daam) (0.1.1)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio->daam) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /usr/local/lib/python3.10/dist-packages (from gradio->daam) (0.41.3)
# Requirement already satisfied: tomlkit==0.12.0 in /usr/local/lib/python3.10/dist-packages (from gradio->daam) (0.12.0)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.10/dist-packages (from gradio->daam) (0.13.0)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.10/dist-packages (from gradio->daam) (4.12.2)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from gradio->daam) (0.32.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from gradio-client==1.4.3->gradio->daam) (2024.10.0)
# Requirement already satisfied: websockets<13.0,>=10.0 in /usr/local/lib/python3.10/dist-packages (from gradio-client==1.4.3->gradio->daam) (12.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->daam) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->daam) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->daam) (2024.2)
# Requirement already satisfied: more-itertools>=8.5.0 in /usr/local/lib/python3.10/dist-packages (from inflect->daam) (10.5.0)
# Requirement already satisfied: typeguard>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from inflect->daam) (4.4.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->daam) (8.1.7)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->daam) (0.43.0)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.10/dist-packages (from scikit-image->daam) (1.13.1)
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.10/dist-packages (from scikit-image->daam) (3.4.2)
# Requirement already satisfied: imageio>=2.33 in /usr/local/lib/python3.10/dist-packages (from scikit-image->daam) (2.36.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image->daam) (2024.9.20)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image->daam) (0.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy->daam) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy->daam) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy->daam) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy->daam) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy->daam) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy->daam) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy->daam) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy->daam) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy->daam) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy->daam) (0.4.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy->daam) (75.1.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy->daam) (3.4.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->gradio->daam) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->gradio->daam) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->gradio->daam) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio->daam) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio->daam) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx>=0.24.1->gradio->daam) (0.14.0)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy->daam) (1.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->gradio->daam) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->gradio->daam) (2.23.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->daam) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers==0.21.2->daam) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers==0.21.2->daam) (2.2.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy->daam) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy->daam) (0.1.5)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.23.0->daam) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.10.0->accelerate==0.23.0->daam) (1.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio->daam) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio->daam) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy->daam) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy->daam) (7.0.5)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.10/dist-packages (from importlib_metadata->diffusers==0.21.2->daam) (3.21.0)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy->daam) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio->daam) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio->daam) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy->daam) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio->daam) (0.1.2)
# Collecting huggingface_hub==0.14.1
#   Using cached huggingface_hub-0.14.1-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub==0.14.1) (3.16.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface_hub==0.14.1) (2024.10.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub==0.14.1) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub==0.14.1) (4.66.6)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub==0.14.1) (6.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub==0.14.1) (4.12.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub==0.14.1) (24.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub==0.14.1) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub==0.14.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub==0.14.1) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub==0.14.1) (2024.8.30)
# Using cached huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
# Installing collected packages: huggingface_hub
#   Attempting uninstall: huggingface_hub
#     Found existing installation: huggingface-hub 0.26.2
#     Uninstalling huggingface-hub-0.26.2:
#       Successfully uninstalled huggingface-hub-0.26.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gradio 5.6.0 requires huggingface-hub>=0.25.1, but you have huggingface-hub 0.14.1 which is incompatible.
# gradio-client 1.4.3 requires huggingface-hub>=0.19.3, but you have huggingface-hub 0.14.1 which is incompatible.
# peft 0.13.2 requires huggingface-hub>=0.17.0, but you have huggingface-hub 0.14.1 which is incompatible.
# sentence-transformers 3.2.1 requires huggingface-hub>=0.20.0, but you have huggingface-hub 0.14.1 which is incompatible.
# sentence-transformers 3.2.1 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.30.2 which is incompatible.
# Successfully installed huggingface_hub-0.14.1

# %%
from daam import trace, set_seed
from diffusers import DiffusionPipeline
import torch
from matplotlib import pyplot as plt
import numpy as np
import os
import cv2
from datetime import datetime

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Set up the base path in Google Drive
base_output_dir = "/content/drive/MyDrive/Generated_Prompts"
os.makedirs(base_output_dir, exist_ok=True)

# Load the Stable Diffusion model and move it to GPU
model_id = 'stabilityai/stable-diffusion-2-1'
pipe = DiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16)
pipe = pipe.to('cuda')

def generate_and_save_images_with_daam(prompt, word_to_trace, seed=0, num_inference_steps=50, threshold=0.08):
    """
    Generate an image with Stable Diffusion, trace attention on a specific word or phrase,
    save both the original image and the DAAM overlay image in PNG and SVG formats,
    and save a binary DAAM mask for IoU comparison.

    Parameters:
        prompt (str): The text prompt for image generation.
        word_to_trace (str): The word or phrase to trace attention on.
        seed (int): The random seed for reproducibility.
        num_inference_steps (int): Number of denoising steps for the pipeline.
        threshold (float): Threshold for binarizing the DAAM mask.
    """
    # Create a unique folder for `word_to_trace` in Google Drive
    trace_dir_name = word_to_trace.replace(" ", "_")  # Replace spaces with underscores for folder naming
    prompt_dir = os.path.join(base_output_dir, trace_dir_name)
    os.makedirs(prompt_dir, exist_ok=True)

    # Set the seed for reproducibility
    gen = set_seed(seed)

    # Use DAAM to trace attention and generate an image
    with torch.no_grad():
        with trace(pipe) as tc:
            out = pipe(prompt, num_inference_steps=num_inference_steps, generator=gen)
            generated_image = out.images[0]

            # Save and show the original image without DAAM overlay
            original_png_path = os.path.join(prompt_dir, "original_image.png")
            generated_image.save(original_png_path)
            print(f"Original image saved as PNG: {original_png_path}")
            plt.imshow(generated_image)
            plt.title("Original Generated Image")
            plt.axis('off')
            plt.show()

            # Compute the global heat map and word-specific heat map
            heat_map = tc.compute_global_heat_map()
            word_heat_map = heat_map.compute_word_heat_map(word_to_trace)
            daam_heatmap = word_heat_map.heatmap.cpu().numpy()  # Get DAAM heatmap as a NumPy array

            # Save DAAM heatmap statistics to a text file
            heatmap_stats_path = os.path.join(prompt_dir, "daam_heatmap_stats.txt")
            with open(heatmap_stats_path, "w") as file:
                file.write(f"DAAM Heatmap Statistics:\n")
                file.write(f"Min: {daam_heatmap.min()}\n")
                file.write(f"Max: {daam_heatmap.max()}\n")
                file.write(f"Mean: {daam_heatmap.mean()}\n")
            print(f"DAAM heatmap statistics saved as text file: {heatmap_stats_path}")
            print(f"DAAM Heatmap - Min: {daam_heatmap.min()}, Max: {daam_heatmap.max()}, Mean: {daam_heatmap.mean()}")

            # Display and save DAAM heatmap before thresholding
            heatmap_svg_path = os.path.join(prompt_dir, "daam_heatmap_before_threshold.svg")
            fig, ax = plt.subplots()
            cax = ax.imshow(daam_heatmap, cmap='hot')
            fig.colorbar(cax)
            plt.title("DAAM Heatmap (Before Thresholding)")
            plt.axis('off')
            fig.savefig(heatmap_svg_path, format="svg", bbox_inches='tight', pad_inches=0)
            plt.show()
            plt.close(fig)
            print(f"DAAM heatmap before thresholding saved as SVG: {heatmap_svg_path}")

            # Threshold the heatmap to create a binary DAAM mask
            daam_binary_mask = (daam_heatmap >= threshold).astype(np.uint8) * 255  # Convert to binary and scale to 0/255

            # Save and show the DAAM binary mask for IoU comparison
            daam_mask_path = os.path.join(prompt_dir, "daam_mask.png")
            cv2.imwrite(daam_mask_path, daam_binary_mask)
            print(f"DAAM binary mask saved as PNG: {daam_mask_path}")
            plt.imshow(daam_binary_mask, cmap='gray')
            plt.title("DAAM Binary Mask")
            plt.axis('off')
            plt.show()

            # Plot the overlayed image
            fig, ax = plt.subplots()
            ax.imshow(generated_image)
            word_heat_map.plot_overlay(generated_image, ax=ax)  # Add overlay to the image
            plt.axis('off')

            # Define filenames for DAAM overlay images
            overlay_png_path = os.path.join(prompt_dir, "image_with_overlay.png")
            overlay_svg_path = os.path.join(prompt_dir, "image_with_overlay.svg")

            # Save and show the DAAM overlay image in PNG and SVG formats
            fig.savefig(overlay_png_path, bbox_inches='tight', pad_inches=0)
            fig.savefig(overlay_svg_path, format="svg", bbox_inches='tight', pad_inches=0)
            print(f"DAAM overlay image saved as PNG: {overlay_png_path}")
            print(f"DAAM overlay image saved as SVG: {overlay_svg_path}")
            plt.show()
            plt.close(fig)

# Example usage
prompt = "A person nervously spilling beans onto the floor, symbolizing the accidental revealing of a secret. The atmosphere is tense, and the background is a modern office."
word_to_trace = "spilling beans"
generate_and_save_images_with_daam(prompt, word_to_trace)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Downloading model_index.json:   0%|          | 0.00/537 [00:00<?, ?B/s]
# Fetching 13 files:   0%|          | 0/13 [00:00<?, ?it/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/824 [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/1.36G [00:00<?, ?B/s]
# Downloading (…)rocessor_config.json:   0%|          | 0.00/342 [00:00<?, ?B/s]
# Downloading tokenizer/vocab.json:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/460 [00:00<?, ?B/s]
# Downloading (…)_encoder/config.json:   0%|          | 0.00/633 [00:00<?, ?B/s]
# Downloading (…)cheduler_config.json:   0%|          | 0.00/345 [00:00<?, ?B/s]
# Downloading tokenizer/merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# Downloading unet/config.json:   0%|          | 0.00/939 [00:00<?, ?B/s]
# Downloading (…)ch_model.safetensors:   0%|          | 0.00/335M [00:00<?, ?B/s]
# Downloading vae/config.json:   0%|          | 0.00/611 [00:00<?, ?B/s]
# Downloading (…)ch_model.safetensors:   0%|          | 0.00/3.46G [00:00<?, ?B/s]
# Loading pipeline components...:   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/daam/utils.py:36: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   return torch.cuda.amp.autocast(*args, **kwargs)
# Original image saved as PNG: /content/drive/MyDrive/Generated_Prompts/spilling_beans/original_image.png
# DAAM heatmap statistics saved as text file: /content/drive/MyDrive/Generated_Prompts/spilling_beans/daam_heatmap_stats.txt
# DAAM Heatmap - Min: 0.13222995400428772, Max: 0.9510927200317383, Mean: 0.3691856563091278
# DAAM heatmap before thresholding saved as SVG: /content/drive/MyDrive/Generated_Prompts/spilling_beans/daam_heatmap_before_threshold.svg
# DAAM binary mask saved as PNG: /content/drive/MyDrive/Generated_Prompts/spilling_beans/daam_mask.png
# DAAM overlay image saved as PNG: /content/drive/MyDrive/Generated_Prompts/spilling_beans/image_with_overlay.png
# DAAM overlay image saved as SVG: /content/drive/MyDrive/Generated_Prompts/spilling_beans/image_with_overlay.svg

# %% [markdown]
# working till here. using data labeling tolls now,

# %%
import xml.etree.ElementTree as ET
import numpy as np
import cv2

def create_mask_from_xml(xml_path, img_shape=(768, 768)):
    """
    Convert XML annotations with bounding boxes from CVAT to a binary mask.

    Parameters:
        xml_path (str): Path to the XML file exported from CVAT.
        img_shape (tuple): The shape of the output mask (height, width).

    Returns:
        np.array: Binary mask where the object is 1 and the background is 0.
    """
    # Initialize an empty binary mask
    mask = np.zeros(img_shape, dtype=np.uint8)

    # Parse the XML file
    tree = ET.parse(xml_path)
    root = tree.getroot()

    # Iterate through each box object in the XML
    for obj in root.findall('image/box'):
        label = obj.attrib['label']

        # Parse the coordinates of the bounding box
        xtl = int(float(obj.attrib['xtl']))
        ytl = int(float(obj.attrib['ytl']))
        xbr = int(float(obj.attrib['xbr']))
        ybr = int(float(obj.attrib['ybr']))

        # Set color based on label
        color = 1 if label == "Object" else 0  # 1 for Object, 0 for Background

        # Draw the rectangle on the mask
        cv2.rectangle(mask, (xtl, ytl), (xbr, ybr), color, thickness=-1)  # -1 fills the rectangle

    return mask

# Paths to the XML file and mask output path
xml_path = '/content/drive/MyDrive/Generated_Prompts/Supreme_Court/annotations.xml'

# Replace with your XML file path  # Replace with your XML file path

# Create the binary mask from the XML file
binary_mask = create_mask_from_xml(xml_path)

# Optional: Save the binary mask as an image file (e.g., PNG)
cv2.imwrite('/content/drive/MyDrive/Generated_Prompts/Supreme_Court/ground_truth_mask.png', binary_mask * 255)  # Save as binary image

print("Ground truth mask created and saved as ground_truth_mask.png")
# Out:
# Ground truth mask created and saved as ground_truth_mask.png

# %% [markdown]
# calculate IoU

# %%
import cv2
import numpy as np

def load_binary_mask(mask_path, target_shape=None):
    """
    Load a binary mask from a file and resize it if necessary.

    Parameters:
        mask_path (str): Path to the binary mask file (PNG format).
        target_shape (tuple): Optional target shape (height, width) to resize the mask.

    Returns:
        np.array: Binary mask where object pixels are 1 and background pixels are 0.
    """
    mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)  # Load as grayscale
    mask = (mask > 0).astype(np.uint8)  # Binarize: 1 for object, 0 for background

    # Resize mask if a target shape is specified
    if target_shape and mask.shape != target_shape:
        mask = cv2.resize(mask, target_shape, interpolation=cv2.INTER_NEAREST)

    return mask

def calculate_iou(daam_mask, ground_truth_mask):
    """
    Calculate the Intersection over Union (IoU) between two binary masks.

    Parameters:
        daam_mask (np.array): Binary mask from DAAM.
        ground_truth_mask (np.array): Ground-truth binary mask from CVAT.

    Returns:
        float: IoU score.
    """
    intersection = np.logical_and(daam_mask, ground_truth_mask).sum()
    union = np.logical_or(daam_mask, ground_truth_mask).sum()
    iou_score = intersection / union if union != 0 else 0
    return iou_score

# Paths to the DAAM and ground-truth masks
daam_mask_path = '/content/drive/MyDrive/Generated_Prompts/Supreme_Court/daam_mask.png'
ground_truth_mask_path = '/content/drive/MyDrive/Generated_Prompts/Supreme_Court/ground_truth_mask.png'

# Load both masks
target_shape = (512, 512)  # Ensure both masks are the same size
daam_mask = load_binary_mask(daam_mask_path, target_shape=target_shape)
ground_truth_mask = load_binary_mask(ground_truth_mask_path, target_shape=target_shape)

# Calculate IoU
iou_score = calculate_iou(daam_mask, ground_truth_mask)
print(f"IoU Score: {iou_score:.2f}")
# Out:
# IoU Score: 0.47

# %% [markdown]
# Generate a Comparison Heatmap

# %%
import matplotlib.pyplot as plt
import numpy as np
import os

def plot_and_save_comparison_heatmap(daam_mask, ground_truth_mask, output_dir, base_filename="comparison_heatmap"):
    """
    Plot a heatmap to compare the DAAM and ground-truth masks, and save it as both PNG and SVG files.

    Parameters:
        daam_mask (np.array): Binary DAAM mask.
        ground_truth_mask (np.array): Binary ground-truth mask.
        output_dir (str): Directory to save the SVG and PNG heatmap files.
        base_filename (str): Base filename for the saved files (without extension).
    """
    # Define colors for different regions
    overlap = np.logical_and(daam_mask, ground_truth_mask)  # Both DAAM and ground truth
    only_daam = np.logical_and(daam_mask, np.logical_not(ground_truth_mask))  # Only DAAM
    only_ground_truth = np.logical_and(ground_truth_mask, np.logical_not(daam_mask))  # Only ground truth

    # Create a blank RGB image to represent the comparison
    comparison = np.zeros((*daam_mask.shape, 3), dtype=np.uint8)

    # Assign colors to different regions
    comparison[overlap] = [0, 255, 0]          # Green: Overlap
    comparison[only_daam] = [255, 0, 0]        # Red: DAAM only
    comparison[only_ground_truth] = [0, 0, 255]  # Blue: Ground truth only

    # Plot the comparison heatmap
    fig, ax = plt.subplots(figsize=(6, 6))
    ax.imshow(comparison)
    ax.set_title("Comparison Heatmap")
    ax.axis('off')

    # Define file paths for PNG and SVG
    png_path = os.path.join(output_dir, f"{base_filename}.png")
    svg_path = os.path.join(output_dir, f"{base_filename}.svg")

    # Save the heatmap as PNG and SVG files
    fig.savefig(png_path, format="png", bbox_inches='tight', pad_inches=0)
    fig.savefig(svg_path, format="svg", bbox_inches='tight', pad_inches=0)
    plt.close(fig)  # Close the figure to free memory
    print(f"Comparison heatmap saved as PNG: {png_path}")
    print(f"Comparison heatmap saved as SVG: {svg_path}")

# Example usage:
output_dir = "/content/drive/MyDrive/Generated_Prompts/Supreme_Court"  # Replace with your output directory path
os.makedirs(output_dir, exist_ok=True)

# Call the function with your loaded masks
plot_and_save_comparison_heatmap(daam_mask, ground_truth_mask, output_dir)
# Out:
# Comparison heatmap saved as PNG: /content/drive/MyDrive/Generated_Prompts/Supreme_Court/comparison_heatmap.png
# Comparison heatmap saved as SVG: /content/drive/MyDrive/Generated_Prompts/Supreme_Court/comparison_heatmap.svg

# %%
import os

def calculate_coverage(daam_mask, ground_truth_mask):
    """
    Calculate DAAM coverage and ground truth coverage metrics.

    Parameters:
        daam_mask (np.array): Binary mask from DAAM.
        ground_truth_mask (np.array): Ground-truth binary mask.

    Returns:
        float, float: DAAM Coverage (%), Ground Truth Coverage (%)
    """
    overlap_area = np.logical_and(daam_mask, ground_truth_mask).sum()
    daam_area = daam_mask.sum()
    ground_truth_area = ground_truth_mask.sum()

    daam_coverage = (overlap_area / daam_area) * 100 if daam_area != 0 else 0
    ground_truth_coverage = (overlap_area / ground_truth_area) * 100 if ground_truth_area != 0 else 0

    return daam_coverage, ground_truth_coverage

# Calculate the coverage metrics
daam_coverage, ground_truth_coverage = calculate_coverage(daam_mask, ground_truth_mask)
print(f"DAAM Coverage: {daam_coverage:.2f}%")
print(f"Ground Truth Coverage: {ground_truth_coverage:.2f}%")

# Define the output directory and filename
output_dir = "/content/drive/MyDrive/Generated_Prompts/Supreme_Court"
os.makedirs(output_dir, exist_ok=True)
results_file_path = os.path.join(output_dir, "coverage_results.txt")

# Save the results to a text file
with open(results_file_path, "w") as file:
    file.write(f"DAAM Coverage: {daam_coverage:.2f}%\n")
    file.write(f"Ground Truth Coverage: {ground_truth_coverage:.2f}%\n")

print(f"Coverage results saved to: {results_file_path}")
# Out:
# DAAM Coverage: 50.76%
# Ground Truth Coverage: 85.40%
# Coverage results saved to: /content/drive/MyDrive/Generated_Prompts/Supreme_Court/coverage_results.txt
